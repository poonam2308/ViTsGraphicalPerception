# %% [markdown]
# # Imports

# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
while not (repo_root / "src").exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root))  

print("Repo root set to:", repo_root)
# Out:
# Repo root set to: /home/poonam/myworkspace/ViTsGraphicalPerception

# %%
from figure1 import Figure1
from figure3 import Figure3
from figure4 import Figure4
from figure12 import Figure12
from weber import Weber
import os, sys, time
import pickle
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(420)

# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Elementary Perceptual Tasks

# %%
sparse, image, label, parameters = Figure1.position_common_scale()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 49 Parameters 60

# %%
sparse, image, label, parameters = Figure1.position_non_aligned_scale()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 29 Parameters 20

# %%
sparse, image, label, parameters = Figure1.length()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 7 Parameters 60

# %%
sparse, image, label, parameters = Figure1.angle()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 64 Parameters 90

# %%
sparse, image, label, parameters = Figure1.direction()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 115 Parameters 360

# %%
sparse, image, label, parameters = Figure1.area()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 2290.221044466959 Parameters 40

# %%
sparse, image, label, parameters = Figure1.volume()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 1331 Parameters 20

# %%
sparse, image, label, parameters = Figure1.curvature()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 0.008 Parameters 80

# %%
sparse, image, label, parameters = Figure1.shading()
print( 'Label', label, 'Parameters', parameters)
imshow(image)
# Out:
# Label 24 Parameters 100

# %% [markdown]
# # Position-angle

# %%
data, labels = Figure3.generate_datapoint()
imshow(Figure3.data_to_barchart(data))

# %%
imshow(Figure3.data_to_piechart(data))

# %%
imshow(Figure3.data_to_piechart_aa(data))

# %% [markdown]
# # Position-Length

# %%
data, labels = Figure4.generate_datapoint()
imshow(Figure4.data_to_type5(data))

# %%
imshow(Figure4.data_to_type1(data))

# %%
imshow(Figure4.data_to_type2(data))

# %%
imshow(Figure4.data_to_type3(data))

# %%
imshow(Figure4.data_to_type4(data))

# %%
imshow(Figure4.data_to_type5(data))

# %%
imshow(Figure4.data_to_type5(data))

# %%
imshow(Figure4.data_to_type4(data))

# %% [markdown]
# # Bar and framed Rectangles

# %%
data, labels, parameters = Figure12.generate_datapoint()
imshow(Figure12.data_to_image(data))

# %%
imshow(Figure12.data_to_image(data, framed=False))

# %% [markdown]
# # Point Cloud Estimation (Weber's Law)

# %%
image, label = Weber.base10()
imshow(image)

# %%
image, label = Weber.base100()
imshow(image)

# %%
image, label = Weber.base1000()
imshow(image)
